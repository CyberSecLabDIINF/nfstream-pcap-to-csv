# %% [markdown]
# # Pruebas para Data Thefts

# %% [markdown]
# ## Inicialización

# %% [markdown]
# ### Importar dependencias

# %%
# Dependencias externas
import pandas as pd

# Dependencias locales
from LabelerV2.modules.matcher import process_tagging
from LabelerV2.modules.config_loader import load_config
from LabelerV2.modules.file_handler import load_csv

from verificator import analyze_labels_in_dataframe

# %% [markdown]
# ### Cargar configuración

# %%
# Cargar configuración
config = load_config(r'LabelerV2/labeler_config.json', "Bot-IoT")

# Mostrar configuración
config
# Out:
# {'Bot-IoT': {'target_csv_key_columns': ['src_ip',
#    'dst_ip',
#    'src_port',
#    'dst_port',
#    'src2dst_packets',
#    'dst2src_packets'],
#   'reference_csv_key_columns': ['saddr',
#    'daddr',
#    'sport',
#    'dport',
#    'spkts',
#    'dpkts'],
#   'column_mapping': {'src_ip': 'saddr',
#    'dst_ip': 'daddr',
#    'src_port': 'sport',
#    'dst_port': 'dport',
#    'src2dst_packets': 'spkts',
#    'dst2src_packets': 'dpkts'},
#   'ports_columns': ['src_port', 'dst_port', 'sport', 'dport'],
#   'columns_to_copy': ['attack', 'category', 'subcategory'],
#   'labeling_files': {'data_theft': 'data_exfiltration',
#    'keylogging': 'keylogging',
#    'http_ddos': 'ddos_http',
#    'udp_ddos': 'ddos_udp',
#    'tcp_ddos': 'ddos_tcp',
#    'http_dos': 'dos_http',
#    'udp_dos': 'dos_udp',
#    'tcp_dos': 'dos_tcp',
#    'osscan': 'os_scan',
#    'servicescan': 'service_scan'}}}

# %% [markdown]
# ## Cargar DataFrames

# %% [markdown]
# ### Cargar DataFrames a etiquetar

# %%
# Cargar DataFrame N°1
df_to_label_01 = load_csv(r'CSVs/f/USACH/Ayudantias/Investigacion-Redes/PCAPs/Bot-IoT/Theft/Data_Exfiltration/IoT_Dataset_data_theft__00001_20180618110503.csv')
df_to_label_01.head(5)
# Out:
#    id  expiration_id          src_ip            src_mac   src_oui  src_port  \
# 0   0              0  192.168.100.46  be:ff:34:42:10:01  be:ff:34        80
# 1   1              0  192.168.100.46  be:ff:34:42:10:01  be:ff:34        80
# 2   2              0   192.168.100.3  00:50:56:be:26:db  00:50:56     60864
# 3   3              0   192.168.100.7  fa:cb:34:12:44:59  fa:cb:34       365
# 4   4              0   192.168.100.6  00:50:56:be:4f:b7  00:50:56       138
#
#             dst_ip            dst_mac   dst_oui  dst_port  ...  \
# 0    192.168.100.5  ae:bb:10:44:55:60  ae:bb:10        80  ...
# 1    192.168.100.5  ae:bb:10:44:55:60  ae:bb:10        80  ...
# 2   172.217.25.138  00:50:56:be:b5:f6  00:50:56       443  ...
# 3    192.168.100.3  ba:ba:ca:6a:00:12  ba:ba:ca       565  ...
# 4  192.168.100.255  ff:ff:ff:ff:ff:ff  ff:ff:ff       138  ...
#
#    dst2src_fin_packets  application_name  application_category_name  \
# ...

# %%
# Cargar DataFrame N°2
df_to_label_02 = load_csv(r'CSVs/f/USACH/Ayudantias/Investigacion-Redes/PCAPs/Bot-IoT/Theft/Data_Exfiltration/IoT_Dataset_data_theft__00002_20180618111101.csv')
df_to_label_02.head(5)
# Out:
#    id  expiration_id          src_ip            src_mac   src_oui  src_port  \
# 0   0              0  192.168.100.46  be:ff:34:42:10:01  be:ff:34        80
# 1   1              0   192.168.100.7  fa:cb:34:12:44:59  fa:cb:34       365
# 2   2              0   192.168.100.3  00:50:56:be:26:db  00:50:56     50850
# 3   3              0  192.168.100.46  be:ff:34:42:10:01  be:ff:34      3456
# 4   4              0  192.168.100.55  ff:ea:24:21:12:13  ff:ea:24      8080
#
#           dst_ip            dst_mac   dst_oui  dst_port  ...  \
# 0  192.168.100.5  ae:bb:10:44:55:60  ae:bb:10        80  ...
# 1  192.168.100.3  ba:ba:ca:6a:00:12  ba:ba:ca       565  ...
# 2   13.54.166.67  00:50:56:be:b5:f6  00:50:56      8883  ...
# 3  192.168.100.5  ae:bb:10:44:55:60  ae:bb:10        80  ...
# 4  192.168.100.3  fa:cb:34:12:44:59  fa:cb:34        80  ...
#
#    dst2src_fin_packets  application_name  application_category_name  \
# 0                    0              HTTP                        Web
# ...

# %%
# Cargar DataFrame N°3
df_to_label_03 = load_csv(r'CSVs/f/USACH/Ayudantias/Investigacion-Redes/PCAPs/Bot-IoT/Theft/Data_Exfiltration/IoT_Dataset_data_theft__00003_20180618111233.csv')
df_to_label_03.head(5)
# Out:
#    id  expiration_id           src_ip            src_mac   src_oui  src_port  \
# 0   0              0    192.168.100.3  00:50:56:be:26:db  00:50:56     50032
# 1   1              0    192.168.100.6  bb:aa:cc:98:55:43  bb:aa:cc        80
# 2   2              0    192.168.100.3  fa:cb:34:12:44:59  fa:cb:34        80
# 3   3              0  192.168.100.149  00:50:56:be:c0:38  00:50:56      4444
# 4   4              0   192.168.100.46  be:ff:34:42:10:01  be:ff:34      3456
#
#             dst_ip            dst_mac   dst_oui  dst_port  ...  \
# 0  192.168.100.150  00:50:56:be:02:54  00:50:56      4433  ...
# 1    192.168.100.3  fa:cb:34:12:44:59  fa:cb:34        80  ...
# 2   192.168.100.55  ff:ea:24:21:12:13  ff:ea:24      8080  ...
# 3    192.168.100.6  00:50:56:be:4f:b7  00:50:56     49160  ...
# 4    192.168.100.5  ae:bb:10:44:55:60  ae:bb:10        80  ...
#
#    dst2src_fin_packets  application_name  application_category_name  \
# ...

# %%
# Cargar DataFrame N°4
df_to_label_04 = load_csv(r'CSVs/f/USACH/Ayudantias/Investigacion-Redes/PCAPs/Bot-IoT/Theft/Data_Exfiltration/IoT_Dataset_data_theft__00004_20180618111334.csv')
df_to_label_04.head(5)
# Out:
#    id  expiration_id          src_ip            src_mac   src_oui  src_port  \
# 0   0              0  192.168.100.46  be:ff:34:42:10:01  be:ff:34      3456
# 1   1              0   192.168.100.6  00:50:56:be:4f:b7  00:50:56     49160
# 2   2              0  192.168.100.46  be:ff:34:42:10:01  be:ff:34        80
# 3   3              0   192.168.100.6  bb:aa:cc:98:55:43  bb:aa:cc        80
# 4   4              0   192.168.100.3  fa:cb:34:12:44:59  fa:cb:34        80
#
#             dst_ip            dst_mac   dst_oui  dst_port  ...  \
# 0    192.168.100.5  ae:bb:10:44:55:60  ae:bb:10        80  ...
# 1  192.168.100.149  00:50:56:be:c0:38  00:50:56      4444  ...
# 2    192.168.100.5  ae:bb:10:44:55:60  ae:bb:10        80  ...
# 3    192.168.100.3  fa:cb:34:12:44:59  fa:cb:34        80  ...
# 4   192.168.100.55  ff:ea:24:21:12:13  ff:ea:24      8080  ...
#
#    dst2src_fin_packets  application_name  application_category_name  \
# ...

# %%
# Cargar DataFrame N°5
df_to_label_05 = load_csv(r'CSVs/f/USACH/Ayudantias/Investigacion-Redes/PCAPs/Bot-IoT/Theft/Data_Exfiltration/IoT_Dataset_data_theft__00005_20180618111434.csv')
df_to_label_05.head(5)
# Out:
#    id  expiration_id          src_ip            src_mac   src_oui  src_port  \
# 0   0              0   192.168.100.6  00:50:56:be:4f:b7  00:50:56     49160
# 1   1              0  192.168.100.46  be:ff:34:42:10:01  be:ff:34        80
# 2   2              0  192.168.100.46  be:ff:34:42:10:01  be:ff:34        80
# 3   3              0   192.168.100.6  bb:aa:cc:98:55:43  bb:aa:cc        80
# 4   4              0   192.168.100.7  fa:cb:34:12:44:59  fa:cb:34       365
#
#             dst_ip            dst_mac   dst_oui  dst_port  ...  \
# 0  192.168.100.149  00:50:56:be:c0:38  00:50:56      4444  ...
# 1    192.168.100.5  ae:bb:10:44:55:60  ae:bb:10        80  ...
# 2    192.168.100.5  ae:bb:10:44:55:60  ae:bb:10        80  ...
# 3    192.168.100.3  fa:cb:34:12:44:59  fa:cb:34        80  ...
# 4    192.168.100.3  ba:ba:ca:6a:00:12  ba:ba:ca       565  ...
#
#    dst2src_fin_packets  application_name  application_category_name  \
# ...

# %%
# Cargar DataFrame N°6
df_to_label_06 = load_csv(r'CSVs/f/USACH/Ayudantias/Investigacion-Redes/PCAPs/Bot-IoT/Theft/Data_Exfiltration/IoT_Dataset_data_theft__00006_20180618111532.csv')
df_to_label_06.head(5)
# Out:
#    id  expiration_id           src_ip            src_mac   src_oui  src_port  \
# 0   0              0   192.168.100.46  be:ff:34:42:10:01  be:ff:34        80
# 1   1              0    192.168.100.6  bb:aa:cc:98:55:43  bb:aa:cc        80
# 2   2              0    192.168.100.3  00:50:56:be:26:db  00:50:56     50032
# 3   3              0    192.168.100.6  00:50:56:be:4f:b7  00:50:56       138
# 4   4              0  192.168.100.149  00:50:56:be:c0:38  00:50:56      4444
#
#             dst_ip            dst_mac   dst_oui  dst_port  ...  \
# 0    192.168.100.5  ae:bb:10:44:55:60  ae:bb:10        80  ...
# 1    192.168.100.3  fa:cb:34:12:44:59  fa:cb:34        80  ...
# 2  192.168.100.150  00:50:56:be:02:54  00:50:56      4433  ...
# 3  192.168.100.255  ff:ff:ff:ff:ff:ff  ff:ff:ff       138  ...
# 4    192.168.100.6  00:50:56:be:4f:b7  00:50:56     49160  ...
#
#    dst2src_fin_packets  application_name  application_category_name  \
# ...

# %%
# Cargar DataFrame N°7
df_to_label_07 = load_csv(r'CSVs/f/USACH/Ayudantias/Investigacion-Redes/PCAPs/Bot-IoT/Theft/Data_Exfiltration/IoT_Dataset_data_theft__00007_20180618111630.csv')
df_to_label_07.head(5)
# Out:
#    id  expiration_id          src_ip            src_mac   src_oui  src_port  \
# 0   0              0   192.168.100.6  00:50:56:be:4f:b7  00:50:56     49160
# 1   1              0  192.168.100.46  be:ff:34:42:10:01  be:ff:34        80
# 2   2              0   192.168.100.6  bb:aa:cc:98:55:43  bb:aa:cc        80
# 3   3              0   192.168.100.7  fa:cb:34:12:44:59  fa:cb:34       365
# 4   4              0   192.168.100.3  00:50:56:be:26:db  00:50:56     50850
#
#             dst_ip            dst_mac   dst_oui  dst_port  ...  \
# 0  192.168.100.149  00:50:56:be:c0:38  00:50:56      4444  ...
# 1    192.168.100.5  ae:bb:10:44:55:60  ae:bb:10        80  ...
# 2    192.168.100.3  fa:cb:34:12:44:59  fa:cb:34        80  ...
# 3    192.168.100.3  ba:ba:ca:6a:00:12  ba:ba:ca       565  ...
# 4     13.54.166.67  00:50:56:be:b5:f6  00:50:56      8883  ...
#
#    dst2src_fin_packets  application_name  application_category_name  \
# ...

# %%
# Cargar DataFrame N°8
df_to_label_08 = load_csv(r'CSVs/f/USACH/Ayudantias/Investigacion-Redes/PCAPs/Bot-IoT/Theft/Data_Exfiltration/IoT_Dataset_data_theft__00008_20180618111730.csv')
df_to_label_08.head(5)
# Out:
#    id  expiration_id          src_ip            src_mac   src_oui  src_port  \
# 0   0              0  192.168.100.46  be:ff:34:42:10:01  be:ff:34        80
# 1   1              0   192.168.100.7  fa:cb:34:12:44:59  fa:cb:34       365
# 2   2              0   192.168.100.6  00:50:56:be:4f:b7  00:50:56     49160
# 3   3              0   192.168.100.3  00:50:56:be:26:db  00:50:56     50850
# 4   4              0   192.168.100.6  bb:aa:cc:98:55:43  bb:aa:cc        80
#
#             dst_ip            dst_mac   dst_oui  dst_port  ...  \
# 0    192.168.100.5  ae:bb:10:44:55:60  ae:bb:10        80  ...
# 1    192.168.100.3  ba:ba:ca:6a:00:12  ba:ba:ca       565  ...
# 2  192.168.100.149  00:50:56:be:c0:38  00:50:56      4444  ...
# 3     13.54.166.67  00:50:56:be:b5:f6  00:50:56      8883  ...
# 4    192.168.100.3  fa:cb:34:12:44:59  fa:cb:34        80  ...
#
#    dst2src_fin_packets  application_name  application_category_name  \
# ...

# %%
# Cargar DataFrame N°9
df_to_label_09 = load_csv(r'CSVs/f/USACH/Ayudantias/Investigacion-Redes/PCAPs/Bot-IoT/Theft/Data_Exfiltration/IoT_Dataset_data_theft__00009_20180618111838.csv')
df_to_label_09.head(5)
# Out:
#    id  expiration_id           src_ip            src_mac   src_oui  src_port  \
# 0   0              0   192.168.100.46  be:ff:34:42:10:01  be:ff:34        80
# 1   1              0    192.168.100.6  bb:aa:cc:98:55:43  bb:aa:cc        80
# 2   2              0  192.168.100.149  00:50:56:be:c0:38  00:50:56      4444
# 3   3              0   192.168.100.46  be:ff:34:42:10:01  be:ff:34        80
# 4   4              0    192.168.100.7  fa:cb:34:12:44:59  fa:cb:34       365
#
#           dst_ip            dst_mac   dst_oui  dst_port  ...  \
# 0  192.168.100.5  ae:bb:10:44:55:60  ae:bb:10        80  ...
# 1  192.168.100.3  fa:cb:34:12:44:59  fa:cb:34        80  ...
# 2  192.168.100.6  00:50:56:be:4f:b7  00:50:56     49160  ...
# 3  192.168.100.5  ae:bb:10:44:55:60  ae:bb:10        80  ...
# 4  192.168.100.3  ba:ba:ca:6a:00:12  ba:ba:ca       565  ...
#
#    dst2src_fin_packets  application_name  application_category_name  \
# ...

# %%
# Cargar DataFrame N°10
df_to_label_10 = load_csv(r'CSVs/f/USACH/Ayudantias/Investigacion-Redes/PCAPs/Bot-IoT/Theft/Data_Exfiltration/IoT_Dataset_data_theft__00010_20180618112008.csv')
df_to_label_10.head(5)
# Out:
#    id  expiration_id           src_ip            src_mac   src_oui  src_port  \
# 0   0              0    192.168.100.3  fa:cb:34:12:44:59  fa:cb:34        80
# 1   1              0    192.168.100.5  ae:bb:10:44:55:60  ae:bb:10        80
# 2   2              0    192.168.100.6  bb:aa:cc:98:55:43  bb:aa:cc        80
# 3   3              0    192.168.100.5  ae:bb:10:44:55:60  ae:bb:10         0
# 4   4              0  192.168.100.150  00:50:56:be:02:54  00:50:56      4433
#
#            dst_ip            dst_mac   dst_oui  dst_port  ...  \
# 0  192.168.100.55  ff:ea:24:21:12:13  ff:ea:24      8080  ...
# 1  192.168.100.46  be:ff:34:42:10:01  be:ff:34      3456  ...
# 2   192.168.100.3  fa:cb:34:12:44:59  fa:cb:34        80  ...
# 3   192.168.100.3  fa:cb:34:12:44:59  fa:cb:34         0  ...
# 4   192.168.100.3  00:50:56:be:26:db  00:50:56     50032  ...
#
#    dst2src_fin_packets  application_name  application_category_name  \
# ...

# %%
# Cargar DataFrame N°11
df_to_label_11 = load_csv(r'CSVs/f/USACH/Ayudantias/Investigacion-Redes/PCAPs/Bot-IoT/Theft/Data_Exfiltration/IoT_Dataset_data_theft__00011_20180618112146.csv')
df_to_label_11.head(5)
# Out:
#    id  expiration_id          src_ip            src_mac   src_oui  src_port  \
# 0   0              0  192.168.100.46  be:ff:34:42:10:01  be:ff:34        80
# 1   1              0   192.168.100.6  00:50:56:be:4f:b7  00:50:56       138
# 2   2              0  192.168.100.46  be:ff:34:42:10:01  be:ff:34        80
# 3   3              0   192.168.100.7  fa:cb:34:12:44:59  fa:cb:34       365
# 4   4              0   192.168.100.3  00:50:56:be:26:db  00:50:56     50850
#
#             dst_ip            dst_mac   dst_oui  dst_port  ...  \
# 0    192.168.100.5  ae:bb:10:44:55:60  ae:bb:10        80  ...
# 1  192.168.100.255  ff:ff:ff:ff:ff:ff  ff:ff:ff       138  ...
# 2    192.168.100.5  ae:bb:10:44:55:60  ae:bb:10        80  ...
# 3    192.168.100.3  ba:ba:ca:6a:00:12  ba:ba:ca       565  ...
# 4     13.54.166.67  00:50:56:be:b5:f6  00:50:56      8883  ...
#
#    dst2src_fin_packets  application_name  application_category_name  \
# ...

# %%
# Cargar DataFrame N°12
df_to_label_12 = load_csv(r'CSVs/f/USACH/Ayudantias/Investigacion-Redes/PCAPs/Bot-IoT/Theft/Data_Exfiltration/IoT_Dataset_data_theft__00012_20180618112555.csv')
df_to_label_12.head(5)
# Out:
#    id  expiration_id           src_ip            src_mac   src_oui  src_port  \
# 0   0              0    192.168.100.6  bb:aa:cc:98:55:43  bb:aa:cc        80
# 1   1              0   192.168.100.46  be:ff:34:42:10:01  be:ff:34      3456
# 2   2              0  192.168.100.149  00:50:56:be:c0:38  00:50:56      4444
# 3   3              0   192.168.100.46  be:ff:34:42:10:01  be:ff:34        80
# 4   4              0   192.168.100.55  ff:ea:24:21:12:13  ff:ea:24      8080
#
#           dst_ip            dst_mac   dst_oui  dst_port  ...  \
# 0  192.168.100.3  fa:cb:34:12:44:59  fa:cb:34        80  ...
# 1  192.168.100.5  ae:bb:10:44:55:60  ae:bb:10        80  ...
# 2  192.168.100.6  00:50:56:be:4f:b7  00:50:56     49160  ...
# 3  192.168.100.5  ae:bb:10:44:55:60  ae:bb:10        80  ...
# 4  192.168.100.3  fa:cb:34:12:44:59  fa:cb:34        80  ...
#
#    dst2src_fin_packets  application_name  application_category_name  \
# ...

# %%
# Cargar DataFrame N°13
df_to_label_13 = load_csv(r'CSVs/f/USACH/Ayudantias/Investigacion-Redes/PCAPs/Bot-IoT/Theft/Data_Exfiltration/IoT_Dataset_data_theft__00013_20180618112736.csv')
df_to_label_13.head(5)
# Out:
#    id  expiration_id           src_ip            src_mac   src_oui  src_port  \
# 0   0              0   192.168.100.46  be:ff:34:42:10:01  be:ff:34        80
# 1   1              0   192.168.100.46  be:ff:34:42:10:01  be:ff:34      3456
# 2   2              0   192.168.100.55  ff:ea:24:21:12:13  ff:ea:24      8080
# 3   3              0    192.168.100.5  ae:bb:10:44:55:60  ae:bb:10         0
# 4   4              0  192.168.100.150  00:50:56:be:02:54  00:50:56      4433
#
#           dst_ip            dst_mac   dst_oui  dst_port  ...  \
# 0  192.168.100.5  ae:bb:10:44:55:60  ae:bb:10        80  ...
# 1  192.168.100.5  ae:bb:10:44:55:60  ae:bb:10        80  ...
# 2  192.168.100.3  fa:cb:34:12:44:59  fa:cb:34        80  ...
# 3  192.168.100.3  fa:cb:34:12:44:59  fa:cb:34         0  ...
# 4  192.168.100.3  00:50:56:be:26:db  00:50:56     50032  ...
#
#    dst2src_fin_packets  application_name  application_category_name  \
# ...

# %% [markdown]
# ### Cargar DataFrame de Referencia

# %%
# Cargar DataFrame de referencia
reference_df = load_csv(r'CSVs/Labeling/Bot-IoT/Data_exfiltration.csv')
reference_df.head(5)
# Out:
#           stime flgs proto            saddr    sport  dir            daddr  \
# 0  1.529284e+09    e   udp    192.168.100.6    138.0   ->  192.168.100.255
# 1  1.529284e+09    e   tcp    192.168.100.3  60864.0  <?>   172.217.25.138
# 2  1.529284e+09    e   udp    192.168.100.7    138.0   ->  192.168.100.255
# 3  1.529284e+09    e   arp  192.168.100.149      NaN  who    192.168.100.6
# 4  1.529284e+09    e   tcp  192.168.100.150  36682.0   ->    192.168.100.3
#
#    dport  pkts  bytes  ... dpkts sbytes  dbytes       rate      srate  \
# 0  138.0     4    986  ...     0    986       0   0.002777   0.002777
# 1  443.0    12   1053  ...     4    697     356   0.098173   0.062473
# 2  138.0     4   1086  ...     0   1086       0   0.004102   0.004102
# 3    NaN    26   1560  ...    13    780     780   0.021496   0.010318
# 4   22.0    28   5098  ...    15   1640    3458  55.147282  24.509903
#
#        drate  record  attack  category        subcategory
# ...

# %% [markdown]
# ## Procesar DataFrames

# %% [markdown]
# ### Data Theft N°1

# %%
# Procesar etiquetado de DataFrames
tagged_df_01 = process_tagging(reference_df, df_to_label_01, "Bot-IoT", config)
tagged_df_01
# Out:
# 2024-12-22 13:35:13 - csv_processor - INFO - Iniciando proceso de etiquetado...
# 2024-12-22 13:35:13 - csv_processor - INFO - Iniciando el proceso de etiquetado...
# 2024-12-22 13:35:13 - csv_processor - INFO - Operando los DataFrames...
# 2024-12-22 13:35:13 - csv_processor - INFO - Proceso de etiquetado completado.
#       id  expiration_id        src_ip            src_mac   src_oui src_port  \
# 0      2              0    1921681003  00:50:56:be:26:db  00:50:56    60864
# 1      6              0  192168100150  00:50:56:be:02:54  00:50:56    36682
# 2      7              0  192168100150  00:50:56:be:02:54  00:50:56    36686
# 3      8              0  192168100150  00:50:56:be:02:54  00:50:56    36692
# 4      9              0  192168100150  00:50:56:be:02:54  00:50:56    36702
# ..   ...            ...           ...                ...       ...      ...
# 108  119              0  192168100150  00:50:56:be:02:54  00:50:56    36864
# ...

# %%
label_counts_01 = analyze_labels_in_dataframe(tagged_df_01)
print("Resultados del análisis del DataFrame:")
for column, counts in label_counts_01.items():
    print(f"Column: {column}")
    for label, count in counts.items():
        print(f"  {label}: {count}")
# Out:
# Resultados del análisis del DataFrame:
# Column: attack
#   1: 110
#   0: 3
# Column: category
#   Theft: 110
#   Normal: 3
# Column: subcategory
#   Data_Exfiltration: 110
#   Normal: 3

# %% [markdown]
# ### Data Theft N°2

# %%
# Procesar etiquetado de DataFrames
tagged_df_02 = process_tagging(reference_df, df_to_label_02, "Bot-IoT", config)
tagged_df_02.head(5)
# Out:
# 2024-12-22 13:35:14 - csv_processor - INFO - Iniciando proceso de etiquetado...
# 2024-12-22 13:35:14 - csv_processor - INFO - Iniciando el proceso de etiquetado...
# 2024-12-22 13:35:14 - csv_processor - INFO - Operando los DataFrames...
# 2024-12-22 13:35:14 - csv_processor - INFO - Proceso de etiquetado completado.
# Empty DataFrame
# ...

# %%
label_counts_02 = analyze_labels_in_dataframe(tagged_df_02)
print("Resultados del análisis del DataFrame:")
for column, counts in label_counts_02.items():
    print(f"Column: {column}")
    for label, count in counts.items():
        print(f"  {label}: {count}")
# Out:
# Resultados del análisis del DataFrame:
# Column: attack
# Column: category
# Column: subcategory

# %% [markdown]
# ### Data Theft N°3

# %%
# Procesar etiquetado de DataFrames
tagged_df_03 = process_tagging(reference_df, df_to_label_03, "Bot-IoT", config)
tagged_df_03.head(5)
# Out:
# 2024-12-22 13:35:14 - csv_processor - INFO - Iniciando proceso de etiquetado...
# 2024-12-22 13:35:14 - csv_processor - INFO - Iniciando el proceso de etiquetado...
# 2024-12-22 13:35:14 - csv_processor - INFO - Operando los DataFrames...
# 2024-12-22 13:35:14 - csv_processor - INFO - Proceso de etiquetado completado.
# Empty DataFrame
# ...

# %%
label_counts_03 = analyze_labels_in_dataframe(tagged_df_03)
print("Resultados del análisis del DataFrame:")
for column, counts in label_counts_03.items():
    print(f"Column: {column}")
    for label, count in counts.items():
        print(f"  {label}: {count}")
# Out:
# Resultados del análisis del DataFrame:
# Column: attack
# Column: category
# Column: subcategory

# %% [markdown]
# ### Data Theft N°4

# %%
# Procesar etiquetado de DataFrames
tagged_df_04 = process_tagging(reference_df, df_to_label_04, "Bot-IoT", config)
tagged_df_04.head(5)
# Out:
# 2024-12-22 13:35:14 - csv_processor - INFO - Iniciando proceso de etiquetado...
# 2024-12-22 13:35:14 - csv_processor - INFO - Iniciando el proceso de etiquetado...
# 2024-12-22 13:35:14 - csv_processor - INFO - Operando los DataFrames...
# 2024-12-22 13:35:14 - csv_processor - INFO - Proceso de etiquetado completado.
# Empty DataFrame
# ...

# %%
label_counts_04 = analyze_labels_in_dataframe(tagged_df_04)
print("Resultados del análisis del DataFrame:")
for column, counts in label_counts_04.items():
    print(f"Column: {column}")
    for label, count in counts.items():
        print(f"  {label}: {count}")
# Out:
# Resultados del análisis del DataFrame:
# Column: attack
# Column: category
# Column: subcategory

# %% [markdown]
# ### Data Theft N°5

# %%
# Procesar etiquetado de DataFrames
tagged_df_05 = process_tagging(reference_df, df_to_label_05, "Bot-IoT", config)
tagged_df_05.head(5)
# Out:
# 2024-12-22 13:35:14 - csv_processor - INFO - Iniciando proceso de etiquetado...
# 2024-12-22 13:35:14 - csv_processor - INFO - Iniciando el proceso de etiquetado...
# 2024-12-22 13:35:14 - csv_processor - INFO - Operando los DataFrames...
# 2024-12-22 13:35:14 - csv_processor - INFO - Proceso de etiquetado completado.
#    id  expiration_id      src_ip            src_mac   src_oui src_port  \
# 0   6              0  1921681006  00:50:56:be:4f:b7  00:50:56    52670
#
#        dst_ip            dst_mac   dst_oui dst_port  ...  \
# 0  1921681001  00:50:56:be:b5:f6  00:50:56       53  ...
#
#    application_is_guessed  application_confidence      requested_server_name  \
# 0                       0                       6  teredo.ipv6.microsoft.com
#
#    client_fingerprint  server_fingerprint  user_agent  content_type  attack  \
# 0                 NaN                 NaN         NaN           NaN       0
#
#    category  subcategory
# 0    Normal       Normal
#
# [1 rows x 89 columns]

# %%
label_counts_05 = analyze_labels_in_dataframe(tagged_df_05)
print("Resultados del análisis del DataFrame:")
for column, counts in label_counts_05.items():
    print(f"Column: {column}")
    for label, count in counts.items():
        print(f"  {label}: {count}")
# Out:
# Resultados del análisis del DataFrame:
# Column: attack
#   0: 1
# Column: category
#   Normal: 1
# Column: subcategory
#   Normal: 1

# %% [markdown]
# ### Data Theft N°6

# %%
# Procesar etiquetado de DataFrames
tagged_df_06 = process_tagging(reference_df, df_to_label_06, "Bot-IoT", config)
tagged_df_06.head(5)
# Out:
# 2024-12-22 13:35:14 - csv_processor - INFO - Iniciando proceso de etiquetado...
# 2024-12-22 13:35:14 - csv_processor - INFO - Iniciando el proceso de etiquetado...
# 2024-12-22 13:35:14 - csv_processor - INFO - Operando los DataFrames...
# 2024-12-22 13:35:14 - csv_processor - INFO - Proceso de etiquetado completado.
# Empty DataFrame
# ...

# %%
label_counts_06 = analyze_labels_in_dataframe(tagged_df_06)
print("Resultados del análisis del DataFrame:")
for column, counts in label_counts_06.items():
    print(f"Column: {column}")
    for label, count in counts.items():
        print(f"  {label}: {count}")
# Out:
# Resultados del análisis del DataFrame:
# Column: attack
# Column: category
# Column: subcategory

# %% [markdown]
# ### Data Theft N°7

# %%
# Procesar etiquetado de DataFrames
tagged_df_07 = process_tagging(reference_df, df_to_label_07, "Bot-IoT", config)
tagged_df_07.head(5)
# Out:
# 2024-12-22 13:35:14 - csv_processor - INFO - Iniciando proceso de etiquetado...
# 2024-12-22 13:35:14 - csv_processor - INFO - Iniciando el proceso de etiquetado...
# 2024-12-22 13:35:14 - csv_processor - INFO - Operando los DataFrames...
# 2024-12-22 13:35:14 - csv_processor - INFO - Proceso de etiquetado completado.
# Empty DataFrame
# ...

# %%
label_counts_07 = analyze_labels_in_dataframe(tagged_df_07)
print("Resultados del análisis del DataFrame:")
for column, counts in label_counts_07.items():
    print(f"Column: {column}")
    for label, count in counts.items():
        print(f"  {label}: {count}")
# Out:
# Resultados del análisis del DataFrame:
# Column: attack
# Column: category
# Column: subcategory

# %% [markdown]
# ### Data Theft N°8

# %%
# Procesar etiquetado de DataFrames
tagged_df_08 = process_tagging(reference_df, df_to_label_08, "Bot-IoT", config)
tagged_df_08.head(5)
# Out:
# 2024-12-22 13:35:15 - csv_processor - INFO - Iniciando proceso de etiquetado...
# 2024-12-22 13:35:15 - csv_processor - INFO - Iniciando el proceso de etiquetado...
# 2024-12-22 13:35:15 - csv_processor - INFO - Operando los DataFrames...
# 2024-12-22 13:35:15 - csv_processor - INFO - Proceso de etiquetado completado.
# Empty DataFrame
# ...

# %%
label_counts_08 = analyze_labels_in_dataframe(tagged_df_08)
print("Resultados del análisis del DataFrame:")
for column, counts in label_counts_08.items():
    print(f"Column: {column}")
    for label, count in counts.items():
        print(f"  {label}: {count}")
# Out:
# Resultados del análisis del DataFrame:
# Column: attack
# Column: category
# Column: subcategory

# %% [markdown]
# ### Data Theft N°9

# %%
# Procesar etiquetado de DataFrames
tagged_df_09 = process_tagging(reference_df, df_to_label_09, "Bot-IoT", config)
tagged_df_09.head(5)
# Out:
# 2024-12-22 13:35:15 - csv_processor - INFO - Iniciando proceso de etiquetado...
# 2024-12-22 13:35:15 - csv_processor - INFO - Iniciando el proceso de etiquetado...
# 2024-12-22 13:35:15 - csv_processor - INFO - Operando los DataFrames...
# 2024-12-22 13:35:15 - csv_processor - INFO - Proceso de etiquetado completado.
#    id  expiration_id        src_ip            src_mac   src_oui src_port  \
# 0   6              0  192168100150  00:50:56:be:02:54  00:50:56    49421
# 1   7              0    1921681004  00:50:56:be:dd:cc  00:50:56    49844
#
#         dst_ip            dst_mac   dst_oui dst_port  ...  \
# 0  27124125251  00:50:56:be:b5:f6  00:50:56      123  ...
# 1     91189944  00:50:56:be:b5:f6  00:50:56      123  ...
#
#    application_is_guessed  application_confidence  requested_server_name  \
# 0                       0                       6                    NaN
# 1                       0                       6                    NaN
#
# ...

# %%
label_counts_09 = analyze_labels_in_dataframe(tagged_df_09)
print("Resultados del análisis del DataFrame:")
for column, counts in label_counts_09.items():
    print(f"Column: {column}")
    for label, count in counts.items():
        print(f"  {label}: {count}")
# Out:
# Resultados del análisis del DataFrame:
# Column: attack
#   0: 2
# Column: category
#   Normal: 2
# Column: subcategory
#   Normal: 2

# %% [markdown]
# ### Data Theft N°10

# %%
# Procesar etiquetado de DataFrames
tagged_df_10 = process_tagging(reference_df, df_to_label_10, "Bot-IoT", config)
tagged_df_10.head(5)
# Out:
# 2024-12-22 13:35:15 - csv_processor - INFO - Iniciando proceso de etiquetado...
# 2024-12-22 13:35:15 - csv_processor - INFO - Iniciando el proceso de etiquetado...
# 2024-12-22 13:35:15 - csv_processor - INFO - Operando los DataFrames...
# 2024-12-22 13:35:15 - csv_processor - INFO - Proceso de etiquetado completado.
#    id  expiration_id      src_ip            src_mac   src_oui src_port  \
# 0   1              0  1921681005  ae:bb:10:44:55:60  ae:bb:10       80
#
#         dst_ip            dst_mac   dst_oui dst_port  ...  \
# 0  19216810046  be:ff:34:42:10:01  be:ff:34     3456  ...
#
#    application_is_guessed  application_confidence  requested_server_name  \
# 0                       0                       0                    NaN
#
#    client_fingerprint  server_fingerprint  user_agent  content_type  attack  \
# 0                 NaN                 NaN         NaN           NaN       0
#
#    category  subcategory
# 0    Normal       Normal
#
# [1 rows x 89 columns]

# %%
label_counts_10 = analyze_labels_in_dataframe(tagged_df_10)
print("Resultados del análisis del DataFrame:")
for column, counts in label_counts_10.items():
    print(f"Column: {column}")
    for label, count in counts.items():
        print(f"  {label}: {count}")
# Out:
# Resultados del análisis del DataFrame:
# Column: attack
#   0: 1
# Column: category
#   Normal: 1
# Column: subcategory
#   Normal: 1

# %% [markdown]
# ### Data Theft N°11

# %%
# Procesar etiquetado de DataFrames
tagged_df_11 = process_tagging(reference_df, df_to_label_11, "Bot-IoT", config)
tagged_df_11.head(5)
# Out:
# 2024-12-22 13:35:15 - csv_processor - INFO - Iniciando proceso de etiquetado...
# 2024-12-22 13:35:15 - csv_processor - INFO - Iniciando el proceso de etiquetado...
# 2024-12-22 13:35:15 - csv_processor - INFO - Operando los DataFrames...
# 2024-12-22 13:35:15 - csv_processor - INFO - Proceso de etiquetado completado.
# Empty DataFrame
# ...

# %%
label_counts_11 = analyze_labels_in_dataframe(tagged_df_11)
print("Resultados del análisis del DataFrame:")
for column, counts in label_counts_11.items():
    print(f"Column: {column}")
    for label, count in counts.items():
        print(f"  {label}: {count}")
# Out:
# Resultados del análisis del DataFrame:
# Column: attack
# Column: category
# Column: subcategory

# %% [markdown]
# ### Data Theft N°12

# %%
# Procesar etiquetado de DataFrames
tagged_df_12 = process_tagging(reference_df, df_to_label_12, "Bot-IoT", config)
tagged_df_12.head(5)
# Out:
# 2024-12-22 13:35:15 - csv_processor - INFO - Iniciando proceso de etiquetado...
# 2024-12-22 13:35:15 - csv_processor - INFO - Iniciando el proceso de etiquetado...
# 2024-12-22 13:35:15 - csv_processor - INFO - Operando los DataFrames...
# 2024-12-22 13:35:15 - csv_processor - INFO - Proceso de etiquetado completado.
# Empty DataFrame
# ...

# %%
label_counts_12 = analyze_labels_in_dataframe(tagged_df_12)
print("Resultados del análisis del DataFrame:")
for column, counts in label_counts_12.items():
    print(f"Column: {column}")
    for label, count in counts.items():
        print(f"  {label}: {count}")
# Out:
# Resultados del análisis del DataFrame:
# Column: attack
# Column: category
# Column: subcategory

# %% [markdown]
# ### Data Theft N°13

# %%
# Procesar etiquetado de DataFrames
tagged_df_13 = process_tagging(reference_df, df_to_label_13, "Bot-IoT", config)
tagged_df_13.head(5)
# Out:
# 2024-12-22 13:35:15 - csv_processor - INFO - Iniciando proceso de etiquetado...
# 2024-12-22 13:35:15 - csv_processor - INFO - Iniciando el proceso de etiquetado...
# 2024-12-22 13:35:15 - csv_processor - INFO - Operando los DataFrames...
# 2024-12-22 13:35:15 - csv_processor - INFO - Proceso de etiquetado completado.
# Empty DataFrame
# ...

# %%
label_counts_13 = analyze_labels_in_dataframe(tagged_df_13)
print("Resultados del análisis del DataFrame:")
for column, counts in label_counts_13.items():
    print(f"Column: {column}")
    for label, count in counts.items():
        print(f"  {label}: {count}")
# Out:
# Resultados del análisis del DataFrame:
# Column: attack
# Column: category
# Column: subcategory
